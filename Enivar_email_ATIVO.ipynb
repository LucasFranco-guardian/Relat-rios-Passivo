# %%
import smtplib
import os
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
from datetime import datetime
from dotenv import load_dotenv

from resumo_ativo import gerar_resumo, resumo_para_html, enviar_whatsapp_grupo

load_dotenv()
# Out:
# True

# %%
# ============================================================
# DATA + CAMINHOS DOS PDFs  (fonte única — edite só a data)
# ============================================================
data = datetime.today().strftime("%d.%m.%Y")   # ou fixe manualmente, ex.: data = "23.07.2026"

DRIVE_ROOT = r"g:\.shortcut-targets-by-id\1YZLLTFOuLniE6hO7WNHXl2c3MSa4TOv6\X. GAME11\GUARDIAN Institucional\5. Planejamento & Processos\2. 2023\4. Research\2025"
pdf_tijolo = rf"{DRIVE_ROOT}\8. Inteligência Ativos Guardian_TIJOLO\Relatorio_Ativo_Tijolo_{data}.pdf"
pdf_papel  = rf"{DRIVE_ROOT}\8. Inteligência Ativos Guardian_PAPEL\Relatorio_Ativo_Papel_{data}.pdf"

print("Data  :", data)
print("Tijolo:", pdf_tijolo)
print("Papel :", pdf_papel)
# Out:
# Data  : 06.08.2026
# Tijolo: g:\.shortcut-targets-by-id\1YZLLTFOuLniE6hO7WNHXl2c3MSa4TOv6\X. GAME11\GUARDIAN Institucional\5. Planejamento & Processos\2. 2023\4. Research\2025\8. Inteligência Ativos Guardian_TIJOLO\Relatorio_Ativo_Tijolo_06.08.2026.pdf
# Papel : g:\.shortcut-targets-by-id\1YZLLTFOuLniE6hO7WNHXl2c3MSa4TOv6\X. GAME11\GUARDIAN Institucional\5. Planejamento & Processos\2. 2023\4. Research\2025\8. Inteligência Ativos Guardian_PAPEL\Relatorio_Ativo_Papel_06.08.2026.pdf

# %%
# ============================================================
# FUNÇÕES DE E-MAIL (corpo HTML com o resumo + PDF em anexo)
# Credencial via .env (senha_gmail) — sem senha hardcoded.
# ============================================================
DESTINATARIOS = [
    'lc@guardian-asset.com', 'pmk@guardian-asset.com', 'msf@guardian-asset.com',
    'cm@guardian-asset.com', 'lb@guardian-asset.com', 'ja@guardian-asset.com',
    'gsa@guardian-asset.com', 'gvm@guardian-asset.com', 'rt@guardian-asset.com',
    'acl@guardian-asset.com', 'lt@guardian-asset.com',
]


def _enviar_email(pdf_path, resumo, assunto, saudacao):
    sender_email = 'lc@guardian-asset.com'
    sender_password = os.getenv("senha_gmail")

    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = ", ".join(DESTINATARIOS)
    msg['Subject'] = assunto

    # Corpo em HTML, com o resumo formatado (negrito, separadores, emojis)
    msg.attach(MIMEText(resumo_para_html(resumo, saudacao=saudacao), 'html'))

    # Anexar o PDF
    try:
        with open(pdf_path, "rb") as attachment:
            part = MIMEBase("application", "octet-stream")
            part.set_payload(attachment.read())
        encoders.encode_base64(part)
        part.add_header(
            "Content-Disposition",
            f"attachment; filename= {os.path.basename(pdf_path)}",
        )
        msg.attach(part)
    except Exception as e:
        print(f"Falha ao anexar o arquivo: {e}")
        return

    # Enviar via SMTP do Gmail
    try:
        with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
            smtp_server.login(sender_email, sender_password)
            smtp_server.sendmail(sender_email, DESTINATARIOS, msg.as_string())
        print(f"E-mail enviado para {', '.join(DESTINATARIOS)}")
    except Exception as e:
        print(f"Falha ao enviar e-mail: {e}")


def send_email_with_pdf_TIJOLO(pdf_path, resumo, data):
    _enviar_email(
        pdf_path, resumo,
        assunto=f"RELATÓRIO DE ATIVO TIJOLO DIA {data}",
        saudacao=f"Prezados, segue o relatório do mercado dos fundos de TIJOLO do dia {data}. Resumo abaixo:",
    )


def send_email_with_pdf_PAPEL(pdf_path, resumo, data):
    _enviar_email(
        pdf_path, resumo,
        assunto=f"RELATÓRIO DE ATIVO PAPEL DIA {data}",
        saudacao=f"Prezados, segue o relatório do mercado dos fundos de PAPEL do dia {data}. Resumo abaixo:",
    )

# %%
# ============================================================
# 1) GERAR os resumos  ->  REVISE / EDITE antes de enviar!
# ============================================================
resumo_tijolo = gerar_resumo(pdf_tijolo, tipo="tijolo")
print(resumo_tijolo)

print("\n" + "=" * 60 + "\n")

resumo_papel = gerar_resumo(pdf_papel, tipo="papel")
print(resumo_papel)

# Se algum número sair errado, basta reatribuir a variável antes de enviar, ex.:
#resumo_tijolo = resumo_tijolo.replace("O saldo de short segue baixo, em R$ 5 mil", "O volume aberto de short foi baixo, em R$ 75 mil")
# Out:
# 🤖 Gerando resumo (tijolo) com o Claude a partir de:
#    g:\.shortcut-targets-by-id\1YZLLTFOuLniE6hO7WNHXl2c3MSa4TOv6\X. GAME11\GUARDIAN Institucional\5. Planejamento & Processos\2. 2023\4. Research\2025\8. Inteligência Ativos Guardian_TIJOLO\Relatorio_Ativo_Tijolo_06.08.2026.pdf
# ✅ Resumo gerado.
# 📅 *Resumo Ativo Tijolo – 06/08/2026*
#
# ⚠️ *TRXF11 desaba -5,3% com liquidez atípica de R$73 MM após anúncio de sua 13ª emissão (R$5,0 BI); GARE11 fecha praticamente estável.*
#
# 🏢 O *GARE11* fechou a *R$ 8,13* (-0,25% no dia), com volume de R$ 10,8 milhões, acima da média de 90 dias (R$ 11,95 milhões). O saldo de short está em 14.711 cotas. No acumulado, cai -1,2% na semana e -0,25% no mês, mas sobe 2,91% desde dez/24. Negocia com P/VP de 0,88 e DY (12M) de 12,25%.
#
# ❗ O *IFIX* recuou -0,58%, aos 3.760 pontos. Na curva de juros, o DI 5 anos subiu 13,50 bps, para 14,27%, enquanto a NTN-B 5 anos avançou 2,00 bps, para 8,27%. O *Ibovespa* caiu -1,2% (176 mil pontos) e o *dólar* recuou -0,6%, cotado a R$ 5,11.
#
# 📌 *Resumo do GARE11*
# 💰 Preço de Fechamento: R$ 8,13
# 🔻 Variação Diária: -0,25%
# 🔻 Variação na Semana: -1,2%
# 🔻 Variação no Mês: -0,25%
# 🟢 Valorização desde dez/24: 2,91%
# 💵 Volume: R$ 10,8 milhões
# 📈 DY (12M): 12,25%
# ⚖️ P/VP: 0,88
#
# 📊 *Principais Peers do GARE11 (VARD)*
# 🔻 HGRU11: -1,65%
# 🔻 TRXF11: -5,32%
# 🔻 HGLG11: -0,50%
# 🔻 BTLG11: -0,60%
# 🔻 XPLG11: -0,31%
# 🟢 KNRI11: 0,51%
#
# 🏗️ *Comportamento das categorias "Prime" (VARD)*
# 🔻 HIB Tijolo Prime: -2,41%
# 🔻 Renda Urbana Prime: -1,65%
# 🔻 Logístico Prime: -0,36%
# 🔻 Shopping Prime: -0,17%
# 🔻 Lajes Prime: -1,06%
#
# 🔔 *Destaque do Dia:* TRXF11 celebrou MoU para aquisição do galpão LOG RECIFE II (R$210 MM, YoC 10,58% e Cap Rate 8,19%) e de portfólio da CY.CAPITAL (4 galpões + 1 escritório em SP, R$2,1 BI), além de aprovar sua 13ª emissão com captação inicial de R$5,0 BI.
#
# ℹ️ *Aviso:* Fundos em oferta: KNHY11 (R$595 MM), GGRC11 (R$1,0 BI), MXRF11 (R$1,0 BI), CPLG11 (R$300 MM) e TRXF11 (R$5,0 BI). Não há fato relevante específico do GARE11 no relatório.
#
# 📌 *Movimentos atípicos*
# ▸ TRXF11 apresentou liquidez atípica de R$73 MM e queda de -5,3%, ligadas ao anúncio de sua 13ª emissão.
#
# ============================================================
#
# 🤖 Gerando resumo (papel) com o Claude a partir de:
#    g:\.shortcut-targets-by-id\1YZLLTFOuLniE6hO7WNHXl2c3MSa4TOv6\X. GAME11\GUARDIAN Institucional\5. Planejamento & Processos\2. 2023\4. Research\2025\8. Inteligência Ativos Guardian_PAPEL\Relatorio_Ativo_Papel_06.08.2026.pdf
# ✅ Resumo gerado.
# 📅 *Resumo Ativo Papel – 06/08/2026*
#
# 🔻 *GAME11 recua -0,61% no dia em pregão de abertura da curva de juros longa (DI +13,5 bps no 5Y).*
#
# 📌 *GAME11 | Fechamento*
# 💰 Preço: *R$ 8,13* (*-0,61%*)
# 📈 Semana: *-1,7%* | Mês: *-1,7%*
# 💵 Volume: *R$ 0,37 mi*
# 📊 DY a.a.: *14,8%* | DY 12M: *14,4%*
# ⚖️ P/VP: *0,87*
#
# 🌐 *Macro do dia*
# ▪️ DI 5Y: 14,27% (*+13,50 bps*) — abertura na parte longa da curva
# ▪️ NTN-B 5Y: 8,27% (*+2,00 bps*)
# ▪️ IBOV: *-1,2%* | Dólar: *-0,6%* (R$ 5,11)
# ▪️ IFIX: *-0,58%* (3.760 pts)
#
# 📊 *Peers*
# ➡️ CPTS11: 0,00% | 🔻 RBRX11: -1,18% | 🔻 VGHF11: -0,95%
# ➡️ MXRF11: 0,00% | 🔻 MANA11: -0,11%
#
# 🏗️ *Setores*
# 🔻 Hedge Fund: -0,56% | 🔻 High Grade: -0,15%
# 🔻 Middle Grade: -0,29% | 🟢 High Yield: +0,37%
#
# ⚡ *Destaques do dia*
# 🔻 *GAME11 caiu -0,61% no dia, desempenho pior que a média do setor Papel (-0,23%) e alinhado ao Fof (-0,62%). Ficou abaixo de peers estáveis como CPTS11 e MXRF11 (0,00%), mas menos pressionado que RBRX11 (-1,18%).*
#
# 📉 *Curva de juros abriu com força nos vértices longos do DI: F35 +15,50 bps (14,47%) e F30 +13,50 bps (14,27%), enquanto a ponta curta ficou quase parada (F27 +0,50 bps). NTN-Bs subiram pouco, com destaque para NTNB35 +8,00 bps.*
#
# 📊 *Maior alta do dia: CACR11 +10,55%. Maiores baixas: URPR11 -2,71%, HFOF11 -1,74% e MFII11 -1,71%.*

# %%
# Se algum número sair errado, basta reatribuir a variável antes de enviar, ex.:
#resumo_tijolo = resumo_tijolo.replace("acima da média de 90 dias", "abaixo da média de 90 dias")
#resumo_papel = resumo_papel.replace("-13,5 bps no vértice curto", "-13,5 bps no vértice de 5 anos")

# %%
print(resumo_tijolo)
# Out:
# 📅 *Resumo Ativo Tijolo – 06/08/2026*
#
# ⚠️ *TRXF11 desaba -5,3% com liquidez atípica de R$73 MM após anúncio de sua 13ª emissão (R$5,0 BI); GARE11 fecha praticamente estável.*
#
# 🏢 O *GARE11* fechou a *R$ 8,13* (-0,25% no dia), com volume de R$ 10,8 milhões, abaixo da média de 90 dias (R$ 11,95 milhões). O saldo de short está em R$14.7 MM. No acumulado, cai -1,2% na semana e -0,25% no mês, mas sobe 2,91% desde dez/24. Negocia com P/VP de 0,88 e DY (12M) de 12,25%.
#
# ❗ O *IFIX* recuou -0,58%, aos 3.760 pontos. Na curva de juros, o DI 5 anos subiu 13,50 bps, para 14,27%, enquanto a NTN-B 5 anos avançou 2,00 bps, para 8,27%. O *Ibovespa* caiu -1,2% (176 mil pontos) e o *dólar* recuou -0,6%, cotado a R$ 5,11.
#
# 📌 *Resumo do GARE11*
# 💰 Preço de Fechamento: R$ 8,13
# 🔻 Variação Diária: -0,25%
# 🔻 Variação na Semana: -1,2%
# 🔻 Variação no Mês: -0,25%
# 🟢 Valorização desde dez/24: 2,91%
# 💵 Volume: R$ 10,8 milhões
# 📈 DY (12M): 12,25%
# ⚖️ P/VP: 0,88
#
# 📊 *Principais Peers do GARE11 (VARD)*
# 🔻 HGRU11: -1,65%
# 🔻 TRXF11: -5,32%
# 🔻 HGLG11: -0,50%
# 🔻 BTLG11: -0,60%
# 🔻 XPLG11: -0,31%
# 🟢 KNRI11: 0,51%
#
# 🏗️ *Comportamento das categorias "Prime" (VARD)*
# 🔻 HIB Tijolo Prime: -2,41%
# 🔻 Renda Urbana Prime: -1,65%
# 🔻 Logístico Prime: -0,36%
# 🔻 Shopping Prime: -0,17%
# 🔻 Lajes Prime: -1,06%
#
# 🔔 *Destaque do Dia:* TRXF11 celebrou MoU para aquisição do galpão LOG RECIFE II (R$210 MM, YoC 10,58% e Cap Rate 8,19%) e de portfólio da CY.CAPITAL (4 galpões + 1 escritório em SP, R$2,1 BI), além de aprovar sua 13ª emissão com captação inicial de R$5,0 BI.
#
# ℹ️ *Aviso:* Fundos em oferta: KNHY11 (R$595 MM), GGRC11 (R$1,0 BI), MXRF11 (R$1,0 BI), CPLG11 (R$300 MM) e TRXF11 (R$5,0 BI). Não há fato relevante específico do GARE11 no relatório.
#
# 📌 *Movimentos atípicos*
# ▸ TRXF11 apresentou liquidez atípica de R$73 MM e queda de -5,3%, ligadas ao anúncio de sua 13ª emissão.

# %%
# ============================================================
# 2) ENVIAR e-mails (execute só depois de revisar os resumos acima)
# ============================================================
send_email_with_pdf_TIJOLO(pdf_tijolo, resumo_tijolo, data)
send_email_with_pdf_PAPEL(pdf_papel, resumo_papel, data)
# Out:
# E-mail enviado para lc@guardian-asset.com, pmk@guardian-asset.com, msf@guardian-asset.com, cm@guardian-asset.com, lb@guardian-asset.com, ja@guardian-asset.com, gsa@guardian-asset.com, gvm@guardian-asset.com, rt@guardian-asset.com, acl@guardian-asset.com, lt@guardian-asset.com
# E-mail enviado para lc@guardian-asset.com, pmk@guardian-asset.com, msf@guardian-asset.com, cm@guardian-asset.com, lb@guardian-asset.com, ja@guardian-asset.com, gsa@guardian-asset.com, gvm@guardian-asset.com, rt@guardian-asset.com, acl@guardian-asset.com, lt@guardian-asset.com

# %%
# ============================================================
# 3) ENVIAR ao grupo de WhatsApp (texto do resumo + PDF como documento)
#    Destino: GRUPO_ATIVO_PHONE definido no .env
#    (para mandar o Papel a OUTRO grupo, passe phone="<id>-group")
# ============================================================
enviar_whatsapp_grupo(resumo_tijolo, pdf_tijolo)
enviar_whatsapp_grupo(resumo_papel, pdf_papel)
# Out:
# ✅ Texto enviado ao WhatsApp (120363401299245523-group). messageId: 2DAA8006C7F8784C01EE
# ✅ PDF enviado ao WhatsApp (120363401299245523-group). messageId: 3EB021032839D71502981C
# ✅ Texto enviado ao WhatsApp (120363401299245523-group). messageId: 3EB07D0E77E3852BE37281
# ✅ PDF enviado ao WhatsApp (120363401299245523-group). messageId: 3EB03E1E9C4C21B7C29FB6
